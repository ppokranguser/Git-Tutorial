# %% [markdown]
# <a href="https://colab.research.google.com/github/ppokranguser/Git-Tutorial/blob/master/helloworld_20214984.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!!")
id = 20214984
print(id)
# Out:
# Hello world
